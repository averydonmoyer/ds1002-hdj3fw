# %% [markdown]
# <a href="https://colab.research.google.com/github/averydonmoyer/ds1002-hdj3fw/blob/main/Class_Exercise_Sept_22_(Pandas).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# import the mackaroo file
mock_data = pd.read_csv("MOCK_DATA.csv")

# %%
# get basic info about the dataframe (df)
mock_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          1000 non-null   int64
#  1   first_name  1000 non-null   object
#  2   last_name   1000 non-null   object
#  3   email       1000 non-null   object
#  4   gender      1000 non-null   object
#  5   age         1000 non-null   int64
# dtypes: int64(2), object(4)
# memory usage: 47.0+ KB

# %%
mock_data.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
# get the head rows - whatever number I want
mock_data.head(3)
# Out:
#    id first_name last_name                        email  gender  age
# 0   1       Jens   Tamlett          jtamlett0@google.de    Male   52
# 1   2     Bunnie    Ruston       bruston1@instagram.com  Female   35
# 2   3    Averill   McInnes  amcinnes2@cocolog-nifty.com    Male   54

# %%
mock_data.tail()
# Out:
#        id first_name   last_name                        email    gender  age
# 995   996    Stewart  Laughtisse    slaughtissern@comsenz.com  Bigender   44
# 996   997       Nina     Bramich    nbramichro@eventbrite.com    Female   19
# 997   998     Emalee     Echalie            eechalierp@si.edu    Female   10
# 998   999    Abigale        Noni              anonirq@umn.edu    Female   32
# 999  1000     Vaughn   Mattessen  vmattessenrr@bravesites.com      Male    9

# %%
# grab a specific row from a df (loc means location)
mock_data.loc[9]
# Out:
# id                            10
# first_name                 Dolli
# last_name                O'Mohun
# email         domohun9@google.fr
# gender                    Female
# age                            6
# Name: 9, dtype: object

# %%
mock_data.describe()
# Out:
#                 id         age
# count  1000.000000  1000.00000
# mean    500.500000    45.32000
# std     288.819436    25.82899
# min       1.000000     1.00000
# 25%     250.750000    23.75000
# 50%     500.500000    44.00000
# 75%     750.250000    69.00000
# max    1000.000000    90.00000

# %%
# get the columns from the df
mock_data.columns
# Out:
# Index(['id', 'first_name', 'last_name', 'email', 'gender', 'age'], dtype='object')

# %%
mock_data.dtypes
# Out:
# id             int64
# first_name    object
# last_name     object
# email         object
# gender        object
# age            int64
# dtype: object

# %%
# rename columns
mock_data = mock_data.rename(columns={"first_name":"fname","last_name":"lname"})

# %%
mock_data.head()
# Out:
#    id    fname    lname                        email  gender  age
# 0   1     Jens  Tamlett          jtamlett0@google.de    Male   52
# 1   2   Bunnie   Ruston       bruston1@instagram.com  Female   35
# 2   3  Averill  McInnes  amcinnes2@cocolog-nifty.com    Male   54
# 3   4   Eirena   Scawen          escawen3@toplist.cz  Female   20
# 4   5   Alfons  Durning         adurning4@nsw.gov.au    Male   53

# %%
mock_data['fname']
# Out:
# 0         Jens
# 1       Bunnie
# 2      Averill
# 3       Eirena
# 4       Alfons
#         ...
# 995    Stewart
# 996       Nina
# 997     Emalee
# 998    Abigale
# 999     Vaughn
# Name: fname, Length: 1000, dtype: object

# %%
mock_data.fname
# Out:
# 0         Jens
# 1       Bunnie
# 2      Averill
# 3       Eirena
# 4       Alfons
#         ...
# 995    Stewart
# 996       Nina
# 997     Emalee
# 998    Abigale
# 999     Vaughn
# Name: fname, Length: 1000, dtype: object

# %%
# this one needs double square brackets
mock_data[['fname','lname']]
# Out:
#        fname       lname
# 0       Jens     Tamlett
# 1     Bunnie      Ruston
# 2    Averill     McInnes
# 3     Eirena      Scawen
# 4     Alfons     Durning
# ..       ...         ...
# 995  Stewart  Laughtisse
# 996     Nina     Bramich
# 997   Emalee     Echalie
# 998  Abigale        Noni
# 999   Vaughn   Mattessen
#
# [1000 rows x 2 columns]

# %%
pd.value_counts(mock_data['gender']).plot.bar()
# Out:
# <Axes: >

# %%
mock_data.groupby(['gender'])['age'].mean()
# Out:
# gender
# Agender        42.000000
# Bigender       56.285714
# Female         44.225322
# Genderfluid    45.937500
# Genderqueer    56.421053
# Male           46.271226
# Non-binary     44.950000
# Polygender     36.363636
# Name: age, dtype: float64
