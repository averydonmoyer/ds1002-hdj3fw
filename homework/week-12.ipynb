# %% [markdown]
# <a href="https://colab.research.google.com/github/averydonmoyer/ds1002-hdj3fw/blob/main/homework/week-12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Pie Chart (3 points)

# %%
# Create a pie chart from raw values

slices = [56, 66, 24, 124, 47]
labels = ["US","UK","MX","CA","JP"]

# %%
import matplotlib.pyplot as plt

plt.pie(slices,labels=['US','UK','MX','CA','JP'])
plt.show()

# %% [markdown]
# ## Histogram (3 points)

# %%
# Create a histogram from random data

import matplotlib.pyplot as plt
import numpy as np

n = 430 + np.random.randn(3000)

# %%
plt.hist(n)
# Out:
# (array([  3.,  35., 130., 377., 719., 796., 579., 270.,  78.,  13.]),
#  array([426.3595918 , 427.04603377, 427.73247575, 428.41891772,
#         429.1053597 , 429.79180168, 430.47824365, 431.16468563,
#         431.8511276 , 432.53756958, 433.22401156]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Scatterplot with Trendline (3 points)

# %%
# Create a scatterplot with a trendline from two lists of values

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

num_points = 50
x = 5 + np.arange(num_points) + np.random.randn(num_points)
y = 10 + np.arange(num_points) + 5 * np.random.randn(num_points)

# If you want them combined into a dataframe
df = pd.DataFrame({'x': x, 'y': y})

# %%
z = np.polyfit(x,y,1)
p = np.poly1d(z)

plt.plot(x,p(x))
plt.scatter(x,y)
